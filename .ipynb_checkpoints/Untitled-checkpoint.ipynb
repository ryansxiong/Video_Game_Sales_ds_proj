# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('vgsales.csv')

# %%
# Genre
    # Top 5 genres (global)
    # Top 5 genres (region)
    # Top 5 games (name) per genre
    # Top genre per year
# Sales
    # Highest sales per year
    # Highest sales (global)
    # highest sales (region)
# Consoles (platform)
    # Top consoles all time (global)
    # Top consoles per year
    # Top consoles (region)
# Publisher
    # Top publishers (count)
    # Top performing publishers (revenue/sales)
# Make line graph for sales over time for each reigion as well as 1 for global

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# getting rid of extra index column
df.drop(columns = 'Rank', inplace = True)

# %%
df.isna().sum()
# Out:
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.shape
# Out:
# (16598, 10)

# %%
df.dtypes
# Out:
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
# Top 5 genres (global)
top_genres = df.groupby(['Genre'])['Global_Sales'].agg('sum')

# %%
top_genres
# Out:
# Genre
# Action          1751.18
# Adventure        239.04
# Fighting         448.91
# Misc             809.96
# Platform         831.37
# Puzzle           244.95
# Racing           732.04
# Role-Playing     927.37
# Shooter         1037.37
# Simulation       392.20
# Sports          1330.93
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %%
top_genres = top_genres.reset_index()

# %%
top_genres
# Out:
#            Genre  Global_Sales
# 0         Action       1751.18
# 1      Adventure        239.04
# 2       Fighting        448.91
# 3           Misc        809.96
# 4       Platform        831.37
# 5         Puzzle        244.95
# 6         Racing        732.04
# 7   Role-Playing        927.37
# 8        Shooter       1037.37
# 9     Simulation        392.20
# 10        Sports       1330.93
# 11      Strategy        175.12

# %%
top_genres = pd.pivot_table(top_genres, values = 'Global_Sales', index = 'Genre')
top_genres = top_genres.sort_values('Global_Sales', ascending = False)

# %%
top_genres
# Out:
#               Global_Sales
# Genre
# Action             1751.18
# Sports             1330.93
# Shooter            1037.37
# Role-Playing        927.37
# Platform            831.37
# Misc                809.96
# Racing              732.04
# Fighting            448.91
# Simulation          392.20
# Puzzle              244.95
# Adventure           239.04
# Strategy            175.12

# %%
top_genres.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global Sales', title = 'Global Sales for Game Genres')
# Out:
# <AxesSubplot:title={'center':'Global Sales for Game Genres'}, xlabel='Genre', ylabel='Global Sales'>

# %%
df.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
# Top 5 genres (region)
na = df.groupby(['Genre'])['NA_Sales'].agg('sum')
eu = df.groupby(['Genre'])['EU_Sales'].agg('sum')
jp = df.groupby(['Genre'])['JP_Sales'].agg('sum')
other = df.groupby(['Genre'])['Other_Sales'].agg('sum')

# %%
# NA sales per genre
na = na.reset_index()
na = pd.pivot_table(na, values = 'NA_Sales', index = 'Genre')
na = na.sort_values('NA_Sales', ascending = False)
na
# Out:
#               NA_Sales
# Genre
# Action          877.83
# Sports          683.35
# Shooter         582.60
# Platform        447.05
# Misc            410.24
# Racing          359.42
# Role-Playing    327.28
# Fighting        223.59
# Simulation      183.31
# Puzzle          123.78
# Adventure       105.80
# Strategy         68.70

# %%
na.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'NA Sales', title = 'NA Sales for Game Genres')
# Out:
# <AxesSubplot:title={'center':'NA Sales for Game Genres'}, xlabel='Genre', ylabel='NA Sales'>

# %%
# EU sales per genre
eu = eu.reset_index()
eu = pd.pivot_table(eu, values = 'EU_Sales', index = 'Genre')
eu = eu.sort_values('EU_Sales', ascending = False)
eu
# Out:
#               EU_Sales
# Genre
# Action          525.00
# Sports          376.85
# Shooter         313.27
# Racing          238.39
# Misc            215.98
# Platform        201.63
# Role-Playing    188.06
# Simulation      113.38
# Fighting        101.32
# Adventure        64.13
# Puzzle           50.78
# Strategy         45.34

# %%
eu.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'EU Sales', title = 'EU Sales for Game Genres')
# Out:
# <AxesSubplot:title={'center':'EU Sales for Game Genres'}, xlabel='Genre', ylabel='EU Sales'>

# %%
# JP sales per genre
jp = jp.reset_index()
jp = pd.pivot_table(jp, values = 'JP_Sales', index = 'Genre')
jp = jp.sort_values('JP_Sales', ascending = False)
jp
# Out:
#               JP_Sales
# Genre
# Role-Playing    352.31
# Action          159.95
# Sports          135.37
# Platform        130.77
# Misc            107.76
# Fighting         87.35
# Simulation       63.70
# Puzzle           57.31
# Racing           56.69
# Adventure        52.07
# Strategy         49.46
# Shooter          38.28

# %%
jp.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'JP Sales', title = 'JP Sales for Game Genres')
# Out:
# <AxesSubplot:title={'center':'JP Sales for Game Genres'}, xlabel='Genre', ylabel='JP Sales'>

# %%
# Top 5 games (name) per genre
top_game = df.groupby(['Genre', 'Name'])['Global_Sales'].agg('sum')
top_game
# Out:
# Genre     Name
# Action    .hack: Sekai no Mukou ni + Versus                                                      0.03
#           007: Quantum of Solace                                                                 3.92
#           007: The World is not Enough                                                           2.47
#           1001 Touch Games                                                                       0.33
#           2 Games in 1 Double Pack: The Incredibles / Finding Nemo: The Continuing Adventures    1.76
#                                                                                                  ...
# Strategy  Zoo Tycoon 2                                                                           0.06
#           Zoo Tycoon 2 DS                                                                        0.30
#           Zoo Tycoon 2: Ultimate Collection                                                      0.26
# ...

# %%
top_game = top_game.reset_index()

# %%
top_game
# Out:
#           Genre                                               Name  \
# 0        Action                  .hack: Sekai no Mukou ni + Versus
# 1        Action                             007: Quantum of Solace
# 2        Action                       007: The World is not Enough
# 3        Action                                   1001 Touch Games
# 4        Action  2 Games in 1 Double Pack: The Incredibles / Fi...
# ...         ...                                                ...
# 11492  Strategy                                       Zoo Tycoon 2
# 11493  Strategy                                    Zoo Tycoon 2 DS
# 11494  Strategy                  Zoo Tycoon 2: Ultimate Collection
# 11495  Strategy                                      Zoo Tycoon DS
# 11496  Strategy                    Zoo Tycoon: Complete Collection
#
#        Global_Sales
# 0              0.03
# 1              3.92
# 2              2.47
# 3              0.33
# 4              1.76
# ...             ...
# ...

# %%
df['Genre'].value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
top_action = top_game[top_game['Genre'].isin(['Action'])]
top_action = top_action.sort_values('Global_Sales', ascending = False)
top_action = top_action.head()
top_action
# Out:
#       Genre                           Name  Global_Sales
# 641  Action             Grand Theft Auto V         55.92
# 644  Action  Grand Theft Auto: San Andreas         23.86
# 640  Action            Grand Theft Auto IV         22.47
# 645  Action    Grand Theft Auto: Vice City         16.19
# 482  Action                 FIFA Soccer 13         16.16

# %%
top_action = pd.pivot_table(top_action, values = 'Global_Sales', index = 'Name')
top_action = top_action.sort_values('Global_Sales', ascending = False)
top_action.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For action Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For action Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_sports = top_game[top_game['Genre'].isin(['Sports'])]
top_sports = top_sports.sort_values('Global_Sales', ascending = False)
top_sports = top_sports.head()
top_sports
# Out:
#         Genre               Name  Global_Sales
# 10827  Sports         Wii Sports         82.74
# 10829  Sports  Wii Sports Resort         33.00
# 10824  Sports            Wii Fit         22.72
# 10825  Sports       Wii Fit Plus         22.00
# 9823   Sports            FIFA 15         19.02

# %%
top_sports = pd.pivot_table(top_sports, values = 'Global_Sales', index = 'Name')
top_sports = top_sports.sort_values('Global_Sales', ascending = False)
top_sports.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For sports Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For sports Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_misc = top_game[top_game['Genre'].isin(['Misc'])]
top_misc = top_misc.sort_values('Global_Sales', ascending = False)
top_misc = top_misc.head()
top_misc
# Out:
#      Genre                                          Name  Global_Sales
# 4845  Misc                                      Wii Play         29.02
# 4266  Misc                                     Minecraft         23.73
# 4164  Misc                            Kinect Adventures!         21.82
# 3679  Misc  Brain Age: Train Your Brain in Minutes a Day         20.22
# 3978  Misc              Guitar Hero III: Legends of Rock         16.40

# %%
top_misc = pd.pivot_table(top_misc, values = 'Global_Sales', index = 'Name')
top_misc = top_misc.sort_values('Global_Sales', ascending = False)
top_misc.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For misc Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For misc Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_Role_Playing = top_game[top_game['Genre'].isin(['Role-Playing'])]
top_Role_Playing = top_Role_Playing.sort_values('Global_Sales', ascending = False)
top_Role_Playing = top_Role_Playing.head()
top_Role_Playing
# Out:
#              Genre                           Name  Global_Sales
# 7581  Role-Playing       Pokemon Red/Pokemon Blue         31.37
# 7572  Role-Playing    Pokemon Gold/Pokemon Silver         23.10
# 7843  Role-Playing    The Elder Scrolls V: Skyrim         19.28
# 7570  Role-Playing  Pokemon Diamond/Pokemon Pearl         18.36
# 7582  Role-Playing  Pokemon Ruby/Pokemon Sapphire         15.85

# %%
top_Role_Playing = pd.pivot_table(top_Role_Playing, values = 'Global_Sales', index = 'Name')
top_Role_Playing = top_Role_Playing.sort_values('Global_Sales', ascending = False)
top_Role_Playing.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For role-playing Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For role-playing Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_Shooter = top_game[top_game['Genre'].isin(['Shooter'])]
top_Shooter = top_Shooter.sort_values('Global_Sales', ascending = False)
top_Shooter = top_Shooter.head()
top_Shooter
# Out:
#         Genre                            Name  Global_Sales
# 8098  Shooter         Call of Duty: Black Ops         31.03
# 8104  Shooter  Call of Duty: Modern Warfare 3         30.83
# 8100  Shooter      Call of Duty: Black Ops II         29.72
# 8222  Shooter                       Duck Hunt         28.31
# 8102  Shooter            Call of Duty: Ghosts         27.38

# %%
top_Shooter = pd.pivot_table(top_Shooter, values = 'Global_Sales', index = 'Name')
top_Shooter = top_Shooter.sort_values('Global_Sales', ascending = False)
top_Shooter.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For shooter Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For shooter Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_Adventure = top_game[top_game['Genre'].isin(['Adventure'])]
top_Adventure = top_Adventure.sort_values('Global_Sales', ascending = False)
top_Adventure = top_Adventure.head()
top_Adventure
# Out:
#           Genre                                Name  Global_Sales
# 1995  Adventure                    Assassin's Creed         11.30
# 2772  Adventure  Super Mario Land 2: 6 Golden Coins         11.18
# 2411  Adventure                          L.A. Noire          5.95
# 2963  Adventure     Zelda II: The Adventure of Link          4.38
# 2647  Adventure          Rugrats: Search For Reptar          3.34

# %%
top_Adventure = pd.pivot_table(top_Adventure, values = 'Global_Sales', index = 'Name')
top_Adventure = top_Adventure.sort_values('Global_Sales', ascending = False)
top_Adventure.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For adventure Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For adventure Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_Racing = top_game[top_game['Genre'].isin(['Racing'])]
top_Racing = top_Racing.sort_values('Global_Sales', ascending = False)
top_Racing = top_Racing.head()
top_Racing
# Out:
#        Genre                         Name  Global_Sales
# 6360  Racing               Mario Kart Wii         35.82
# 6359  Racing                Mario Kart DS         23.42
# 6256  Racing       Gran Turismo 3: A-Spec         14.98
# 6477  Racing  Need for Speed: Most Wanted         14.08
# 6357  Racing                 Mario Kart 7         12.21

# %%
top_Racing = pd.pivot_table(top_Racing, values = 'Global_Sales', index = 'Name')
top_Racing = top_Racing.sort_values('Global_Sales', ascending = False)
top_Racing.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For racing Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For racing Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_Platform = top_game[top_game['Genre'].isin(['Platform'])]
top_Platform = top_Platform.sort_values('Global_Sales', ascending = False)
top_Platform = top_Platform.head()
top_Platform
# Out:
#          Genre                       Name  Global_Sales
# 5401  Platform          Super Mario Bros.         45.31
# 5231  Platform      New Super Mario Bros.         30.01
# 5234  Platform  New Super Mario Bros. Wii         28.62
# 5411  Platform          Super Mario World         26.07
# 5403  Platform        Super Mario Bros. 3         22.48

# %%
top_Platform = pd.pivot_table(top_Platform, values = 'Global_Sales', index = 'Name')
top_Platform = top_Platform.sort_values('Global_Sales', ascending = False)
top_Platform.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For platform Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For platform Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_Simulation = top_game[top_game['Genre'].isin(['Simulation'])]
top_Simulation = top_Simulation.sort_values('Global_Sales', ascending = False)
top_Simulation = top_Simulation.head()
top_Simulation
# Out:
#            Genre                         Name  Global_Sales
# 9246  Simulation                   Nintendogs         24.76
# 9435  Simulation                   The Sims 3         15.45
# 8846  Simulation  Animal Crossing: Wild World         12.27
# 8845  Simulation    Animal Crossing: New Leaf          9.09
# 8923  Simulation                 Cooking Mama          5.72

# %%
top_Simulation = pd.pivot_table(top_Simulation, values = 'Global_Sales', index = 'Name')
top_Simulation = top_Simulation.sort_values('Global_Sales', ascending = False)
top_Simulation.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For simulation Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For simulation Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_Fighting = top_game[top_game['Genre'].isin(['Fighting'])]
top_Fighting = top_Fighting.sort_values('Global_Sales', ascending = False)
top_Fighting = top_Fighting.head()
top_Fighting
# Out:
#          Genre                                 Name  Global_Sales
# 3433  Fighting              Super Smash Bros. Brawl         13.04
# 3435  Fighting  Super Smash Bros. for Wii U and 3DS         12.47
# 3268  Fighting                        Mortal Kombat          8.40
# 3538  Fighting            WWE SmackDown vs Raw 2008          7.41
# 3419  Fighting                    Street Fighter IV          7.27

# %%
top_Fighting = pd.pivot_table(top_Fighting, values = 'Global_Sales', index = 'Name')
top_Fighting = top_Fighting.sort_values('Global_Sales', ascending = False)
top_Fighting.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For fighting Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For fighting Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_Strategy = top_game[top_game['Genre'].isin(['Strategy'])]
top_Strategy = top_Strategy.sort_values('Global_Sales', ascending = False)
top_Strategy = top_Strategy.head()
top_Strategy
# Out:
#           Genre                            Name  Global_Sales
# 11218  Strategy                 Pokemon Stadium          5.45
# 11445  Strategy                    Warzone 2100          5.01
# 11327  Strategy  StarCraft II: Wings of Liberty          4.83
# 11431  Strategy  Warcraft II: Tides of Darkness          4.21
# 11220  Strategy       Pokémon Trading Card Game          3.70

# %%
top_Strategy = pd.pivot_table(top_Strategy, values = 'Global_Sales', index = 'Name')
top_Strategy = top_Strategy.sort_values('Global_Sales', ascending = False)
top_Strategy.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For Strategy Games')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For Strategy Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
top_Puzzle = top_game[top_game['Genre'].isin(['Puzzle'])]
top_Puzzle = top_Puzzle.sort_values('Global_Sales', ascending = False)
top_Puzzle = top_Puzzle.head()
top_Puzzle
# Out:
#        Genre                                         Name  Global_Sales
# 5923  Puzzle                                       Tetris         35.84
# 5557  Puzzle  Brain Age 2: More Training in Minutes a Day         15.30
# 5623  Puzzle                                    Dr. Mario         10.19
# 5797  Puzzle                                      Pac-Man          9.03
# 5822  Puzzle     Professor Layton and the Curious Village          5.26

# %%
top_Puzzle = pd.pivot_table(top_Puzzle, values = 'Global_Sales', index = 'Name')
top_Puzzle = top_Puzzle.sort_values('Global_Sales', ascending = False)
top_Puzzle.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For Puzzle Games', legend = False)
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For Puzzle Games'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
games = pd.concat([top_Puzzle, top_Strategy, top_Fighting, top_Simulation, top_Platform, top_Racing, top_Adventure, top_Shooter, top_Role_Playing, top_misc, top_sports, top_action])
games
# Out:
#                                               Global_Sales
# Name
# Tetris                                               35.84
# Brain Age 2: More Training in Minutes a Day          15.30
# Dr. Mario                                            10.19
# Pac-Man                                               9.03
# Professor Layton and the Curious Village              5.26
# Pokemon Stadium                                       5.45
# Warzone 2100                                          5.01
# StarCraft II: Wings of Liberty                        4.83
# Warcraft II: Tides of Darkness                        4.21
# Pokémon Trading Card Game                             3.70
# Super Smash Bros. Brawl                              13.04
# Super Smash Bros. for Wii U and 3DS                  12.47
# Mortal Kombat                                         8.40
# WWE SmackDown vs Raw 2008                             7.41
# Street Fighter IV                                     7.27
# ...

# %%
t1 = pd.pivot_table(games, values = 'Global_Sales', index = 'Genre', columns = 'Name')
t1.plot(kind = 'bar', figsize = (16, 9), xlabel = 'Genre', ylabel = 'Global_Sales', title = 'Top 5 Games For Every Genre', legend = False, width = 3)
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For Every Genre'}, xlabel='Genre', ylabel='Global_Sales'>

# %%
df.head()
# Out:
#                        Name Platform    Year         Genre Publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Sales over time for each region
global_sale = df.groupby(['Year'])['Global_Sales'].agg('sum').reset_index()
NA = df.groupby(['Year'])['NA_Sales'].agg('sum').reset_index()
EU = df.groupby(['Year'])['EU_Sales'].agg('sum').reset_index()
JP = df.groupby(['Year'])['JP_Sales'].agg('sum').reset_index()

# %%
a = pd.concat([global_sale, NA, EU, JP])
a
# Out:
#       Year  Global_Sales  NA_Sales  EU_Sales  JP_Sales
# 0   1980.0         11.38       NaN       NaN       NaN
# 1   1981.0         35.77       NaN       NaN       NaN
# 2   1982.0         28.86       NaN       NaN       NaN
# 3   1983.0         16.79       NaN       NaN       NaN
# 4   1984.0         50.36       NaN       NaN       NaN
# ..     ...           ...       ...       ...       ...
# 34  2014.0           NaN       NaN       NaN     39.46
# 35  2015.0           NaN       NaN       NaN     33.72
# 36  2016.0           NaN       NaN       NaN     13.70
# 37  2017.0           NaN       NaN       NaN      0.05
# 38  2020.0           NaN       NaN       NaN      0.00
#
# [156 rows x 5 columns]

# %%
a.plot(kind = 'line', x = 'Year', figsize = (16, 9))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
global_sale
# Out:
#       Year  Global_Sales
# 0   1980.0         11.38
# 1   1981.0         35.77
# 2   1982.0         28.86
# 3   1983.0         16.79
# 4   1984.0         50.36
# 5   1985.0         53.94
# 6   1986.0         37.07
# 7   1987.0         21.74
# 8   1988.0         47.22
# 9   1989.0         73.45
# 10  1990.0         49.39
# 11  1991.0         32.23
# 12  1992.0         76.16
# 13  1993.0         45.98
# 14  1994.0         79.17
# 15  1995.0         88.11
# 16  1996.0        199.15
# 17  1997.0        200.98
# 18  1998.0        256.47
# 19  1999.0        251.27
# 20  2000.0        201.56
# 21  2001.0        331.47
# 22  2002.0        395.52
# 23  2003.0        357.85
# 24  2004.0        419.31
# 25  2005.0        459.94
# 26  2006.0        521.04
# 27  2007.0        611.13
# 28  2008.0        678.90
# 29  2009.0        667.30
# 30  2010.0        600.45
# 31  2011.0        515.99
# 32  2012.0        363.54
# 33  2013.0        368.11
# 34  2014.0        337.05
# 35  2015.0        264.44
# ...

# %%
# Top genre per year
top_year = df.groupby(['Genre', 'Year'])['Global_Sales'].agg('sum')
top_year
# Out:
# Genre     Year
# Action    1980.0     0.34
#           1981.0    14.84
#           1982.0     6.52
#           1983.0     2.86
#           1984.0     1.85
#                     ...
# Strategy  2012.0     3.33
#           2013.0     6.33
#           2014.0     0.99
#           2015.0     1.82
#           2016.0     0.50
# Name: Global_Sales, Length: 389, dtype: float64

# %%
top_year = top_year.reset_index()
top_year
# Out:
#         Genre    Year  Global_Sales
# 0      Action  1980.0          0.34
# 1      Action  1981.0         14.84
# 2      Action  1982.0          6.52
# 3      Action  1983.0          2.86
# 4      Action  1984.0          1.85
# ..        ...     ...           ...
# 384  Strategy  2012.0          3.33
# 385  Strategy  2013.0          6.33
# 386  Strategy  2014.0          0.99
# 387  Strategy  2015.0          1.82
# 388  Strategy  2016.0          0.50
#
# [389 rows x 3 columns]

# %%
t2 = top_year.groupby('Year')['Global_Sales'].max().reset_index()
t2
# Out:
#       Year  Global_Sales
# 0   1980.0          7.07
# 1   1981.0         14.84
# 2   1982.0         10.03
# 3   1983.0          6.93
# 4   1984.0         31.10
# 5   1985.0         43.17
# 6   1986.0         13.74
# 7   1987.0          5.42
# 8   1988.0         27.73
# 9   1989.0         37.75
# 10  1990.0         22.97
# 11  1991.0          7.64
# 12  1992.0         15.25
# 13  1993.0         18.67
# 14  1994.0         28.74
# 15  1995.0         16.69
# 16  1996.0         43.96
# 17  1997.0         31.91
# 18  1998.0         41.79
# 19  1999.0         49.09
# 20  2000.0         41.19
# 21  2001.0         59.39
# 22  2002.0         86.77
# 23  2003.0         67.93
# 24  2004.0         76.26
# 25  2005.0         85.69
# 26  2006.0        136.16
# 27  2007.0        106.50
# 28  2008.0        136.39
# 29  2009.0        139.36
# 30  2010.0        117.64
# 31  2011.0        118.96
# 32  2012.0        122.04
# 33  2013.0        125.22
# 34  2014.0         99.02
# 35  2015.0         70.70
# ...

# %%
top_year = pd.pivot_table(top_year, values = ['Global_Sales'], index = ['Year', 'Genre'])
top_year
# Out:
#                      Global_Sales
# Year   Genre
# 1980.0 Action                0.34
#        Fighting              0.77
#        Misc                  2.71
#        Shooter               7.07
#        Sports                0.49
# ...                           ...
# 2016.0 Sports               14.60
#        Strategy              0.50
# 2017.0 Action                0.01
#        Role-Playing          0.04
# 2020.0 Simulation            0.29
#
# [389 rows x 1 columns]

# %%
t1 = top_year.groupby(['Year'])['Global_Sales'].idxmax().reset_index()
t1
# Out:
#       Year            Global_Sales
# 0   1980.0       (1980.0, Shooter)
# 1   1981.0        (1981.0, Action)
# 2   1982.0        (1982.0, Puzzle)
# 3   1983.0      (1983.0, Platform)
# 4   1984.0       (1984.0, Shooter)
# 5   1985.0      (1985.0, Platform)
# 6   1986.0        (1986.0, Action)
# 7   1987.0      (1987.0, Fighting)
# 8   1988.0      (1988.0, Platform)
# 9   1989.0        (1989.0, Puzzle)
# 10  1990.0      (1990.0, Platform)
# 11  1991.0      (1991.0, Platform)
# 12  1992.0      (1992.0, Fighting)
# 13  1993.0      (1993.0, Platform)
# 14  1994.0      (1994.0, Platform)
# 15  1995.0      (1995.0, Platform)
# 16  1996.0  (1996.0, Role-Playing)
# 17  1997.0        (1997.0, Racing)
# 18  1998.0        (1998.0, Sports)
# 19  1999.0  (1999.0, Role-Playing)
# 20  2000.0        (2000.0, Sports)
# 21  2001.0        (2001.0, Action)
# 22  2002.0        (2002.0, Action)
# 23  2003.0        (2003.0, Action)
# 24  2004.0        (2004.0, Action)
# 25  2005.0        (2005.0, Action)
# ...

# %%
t1['year, genre'] = t1['Global_Sales']

# %%
t1 = t1.drop(columns = ['Year', 'Global_Sales'])
t1
# Out:
#                year, genre
# 0        (1980.0, Shooter)
# 1         (1981.0, Action)
# 2         (1982.0, Puzzle)
# 3       (1983.0, Platform)
# 4        (1984.0, Shooter)
# 5       (1985.0, Platform)
# 6         (1986.0, Action)
# 7       (1987.0, Fighting)
# 8       (1988.0, Platform)
# 9         (1989.0, Puzzle)
# 10      (1990.0, Platform)
# 11      (1991.0, Platform)
# 12      (1992.0, Fighting)
# 13      (1993.0, Platform)
# 14      (1994.0, Platform)
# 15      (1995.0, Platform)
# 16  (1996.0, Role-Playing)
# 17        (1997.0, Racing)
# 18        (1998.0, Sports)
# 19  (1999.0, Role-Playing)
# 20        (2000.0, Sports)
# 21        (2001.0, Action)
# 22        (2002.0, Action)
# 23        (2003.0, Action)
# 24        (2004.0, Action)
# 25        (2005.0, Action)
# 26        (2006.0, Sports)
# 27        (2007.0, Action)
# 28        (2008.0, Action)
# 29        (2009.0, Action)
# 30        (2010.0, Action)
# 31        (2011.0, Action)
# 32        (2012.0, Action)
# ...

# %%
t1['year'] = t1['year, genre'].astype(str).str[1:5]

# %%
t1['genre'] = t1['year, genre'].astype(str).str[8:-1]

# %%
t1 = t1.drop(columns = 'year, genre')

# %%
t1['genre']
# Out:
# 0           'Shooter'
# 1            'Action'
# 2            'Puzzle'
# 3          'Platform'
# 4           'Shooter'
# 5          'Platform'
# 6            'Action'
# 7          'Fighting'
# 8          'Platform'
# 9            'Puzzle'
# 10         'Platform'
# 11         'Platform'
# 12         'Fighting'
# 13         'Platform'
# 14         'Platform'
# 15         'Platform'
# 16     'Role-Playing'
# 17           'Racing'
# 18           'Sports'
# 19     'Role-Playing'
# 20           'Sports'
# 21           'Action'
# 22           'Action'
# 23           'Action'
# 24           'Action'
# 25           'Action'
# 26           'Sports'
# 27           'Action'
# 28           'Action'
# 29           'Action'
# 30           'Action'
# 31           'Action'
# 32           'Action'
# 33           'Action'
# 34           'Action'
# 35           'Action'
# 36           'Action'
# 37     'Role-Playing'
# 38       'Simulation'
# Name: genre, dtype: object

# %%
t1['year']
# Out:
# 0     1980
# 1     1981
# 2     1982
# 3     1983
# 4     1984
# 5     1985
# 6     1986
# 7     1987
# 8     1988
# 9     1989
# 10    1990
# 11    1991
# 12    1992
# 13    1993
# 14    1994
# 15    1995
# 16    1996
# 17    1997
# 18    1998
# 19    1999
# 20    2000
# 21    2001
# 22    2002
# 23    2003
# 24    2004
# 25    2005
# 26    2006
# 27    2007
# 28    2008
# 29    2009
# 30    2010
# 31    2011
# 32    2012
# 33    2013
# 34    2014
# 35    2015
# 36    2016
# 37    2017
# 38    2020
# Name: year, dtype: object

# %%
t2 = t2.drop(columns = ['Year'])
t2
# Out:
#     Global_Sales
# 0           7.07
# 1          14.84
# 2          10.03
# 3           6.93
# 4          31.10
# 5          43.17
# 6          13.74
# 7           5.42
# 8          27.73
# 9          37.75
# 10         22.97
# 11          7.64
# 12         15.25
# 13         18.67
# 14         28.74
# 15         16.69
# 16         43.96
# 17         31.91
# 18         41.79
# 19         49.09
# 20         41.19
# 21         59.39
# 22         86.77
# 23         67.93
# 24         76.26
# 25         85.69
# 26        136.16
# 27        106.50
# 28        136.39
# 29        139.36
# 30        117.64
# 31        118.96
# 32        122.04
# 33        125.22
# 34         99.02
# 35         70.70
# 36         19.91
# 37          0.04
# 38          0.29

# %%
# new table for top genre per year
t3 = pd.merge(t1, t2, left_index=True, right_index=True)
t3
# Out:
#     year            genre  Global_Sales
# 0   1980        'Shooter'          7.07
# 1   1981         'Action'         14.84
# 2   1982         'Puzzle'         10.03
# 3   1983       'Platform'          6.93
# 4   1984        'Shooter'         31.10
# 5   1985       'Platform'         43.17
# 6   1986         'Action'         13.74
# 7   1987       'Fighting'          5.42
# 8   1988       'Platform'         27.73
# 9   1989         'Puzzle'         37.75
# 10  1990       'Platform'         22.97
# 11  1991       'Platform'          7.64
# 12  1992       'Fighting'         15.25
# 13  1993       'Platform'         18.67
# 14  1994       'Platform'         28.74
# 15  1995       'Platform'         16.69
# 16  1996   'Role-Playing'         43.96
# 17  1997         'Racing'         31.91
# 18  1998         'Sports'         41.79
# 19  1999   'Role-Playing'         49.09
# 20  2000         'Sports'         41.19
# 21  2001         'Action'         59.39
# ...

# %%
t3['genre'].value_counts()
# Out:
#  'Action'          17
#  'Platform'         8
#  'Sports'           3
#  'Role-Playing'     3
#  'Fighting'         2
#  'Puzzle'           2
#  'Shooter'          2
#  'Simulation'       1
#  'Racing'           1
# Name: genre, dtype: int64

# %%
df.head()
# Out:
#                        Name Platform    Year         Genre Publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df[df['Global_Sales'] == df['Global_Sales'].max()]
# Out:
#          Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
# top game of all time (global)
df.iloc[df['Global_Sales']].max()
# Out:
# Name               Wii Sports Resort
# Platform                        X360
# Year                          2015.0
# Genre                         Sports
# Publisher       Take-Two Interactive
# NA_Sales                       41.49
# EU_Sales                       29.02
# JP_Sales                       10.22
# Other_Sales                    10.57
# Global_Sales                   82.74
# dtype: object

# %%
# top game NA
df.iloc[df['NA_Sales']].max()
# Out:
# Name               Wii Sports Resort
# Platform                        X360
# Year                          2013.0
# Genre                         Sports
# Publisher       Take-Two Interactive
# NA_Sales                       41.49
# EU_Sales                       29.02
# JP_Sales                       10.22
# Other_Sales                     8.46
# Global_Sales                   82.74
# dtype: object

# %%
# top game EU
df.iloc[df['EU_Sales']].max()
# Out:
# Name            Wii Sports Resort
# Platform                     X360
# Year                       2011.0
# Genre                      Sports
# Publisher                Nintendo
# NA_Sales                    41.49
# EU_Sales                    29.02
# JP_Sales                    10.22
# Other_Sales                  8.46
# Global_Sales                82.74
# dtype: object

# %%
# top game JP
df.iloc[df['JP_Sales']].max()
# Out:
# Name            Wii Sports Resort
# Platform                      Wii
# Year                       2009.0
# Genre                      Sports
# Publisher                Nintendo
# NA_Sales                    41.49
# EU_Sales                    29.02
# JP_Sales                    10.22
# Other_Sales                  8.46
# Global_Sales                82.74
# dtype: object

# %%
# top game other
df.iloc[df['Other_Sales']].max()
# Out:
# Name            Wii Sports Resort
# Platform                      Wii
# Year                       2009.0
# Genre                      Sports
# Publisher                Nintendo
# NA_Sales                    41.49
# EU_Sales                    29.02
# JP_Sales                    10.22
# Other_Sales                  8.46
# Global_Sales                82.74
# dtype: object

# %%
# looking at the top game per reigon, it is the same game but the platform is different

# %%
# Top Selling Game for each year
x = 1980.0
while x <= 2020.0:
    df1 = df[df['Year'] == x].max()
    print(df1)
    x = x + 1
# Out:
# Name            Missile Command
# Platform                   2600
# Year                     1980.0
# Genre                    Sports
# Publisher                 Atari
# NA_Sales                    4.0
# EU_Sales                   0.26
# JP_Sales                    0.0
# Other_Sales                0.05
# Global_Sales               4.31
# dtype: object
# Name            Spider-Man
# Platform              2600
# Year                1981.0
# Genre               Sports
# Publisher          Unknown
# NA_Sales              4.21
# EU_Sales              0.24
# JP_Sales               0.0
# Other_Sales           0.05
# Global_Sales           4.5
# dtype: object
# Name                 Yars' Revenge
# Platform                      2600
# Year                        1982.0
# Genre                       Sports
# Publisher       Wizard Video Games
# NA_Sales                      7.28
# EU_Sales                      0.45
# JP_Sales                       0.0
# Other_Sales                   0.08
# ...

# %%
d1 = df.groupby(['Year'])['Global_Sales'].max().reset_index()
d1
# Out:
#       Year  Global_Sales
# 0   1980.0          4.31
# 1   1981.0          4.50
# 2   1982.0          7.81
# 3   1983.0          3.20
# 4   1984.0         28.31
# 5   1985.0         40.24
# 6   1986.0          6.51
# 7   1987.0          4.38
# 8   1988.0         17.28
# 9   1989.0         30.26
# 10  1990.0         20.61
# 11  1991.0          4.61
# 12  1992.0         11.18
# 13  1993.0         10.55
# 14  1994.0          9.30
# 15  1995.0          5.15
# 16  1996.0         31.37
# 17  1997.0         10.95
# 18  1998.0         14.64
# 19  1999.0         23.10
# 20  2000.0          6.39
# 21  2001.0         14.98
# 22  2002.0         16.15
# 23  2003.0          7.20
# 24  2004.0         20.81
# 25  2005.0         24.76
# 26  2006.0         82.74
# 27  2007.0         22.72
# 28  2008.0         35.82
# 29  2009.0         33.00
# 30  2010.0         21.82
# 31  2011.0         14.76
# 32  2012.0         14.03
# 33  2013.0         21.40
# 34  2014.0         11.98
# 35  2015.0         14.24
# ...

# %%
df[df['Year'] == 2015.0]
# Out:
#                                                     Name Platform    Year  \
# 33                             Call of Duty: Black Ops 3      PS4  2015.0
# 77                                               FIFA 16      PS4  2015.0
# 92                          Star Wars Battlefront (2015)      PS4  2015.0
# 101                            Call of Duty: Black Ops 3     XOne  2015.0
# 109                                            Fallout 4      PS4  2015.0
# ...                                                  ...      ...     ...
# 16499         Irotoridori no Sekai: World's End Re-Birth      PSV  2015.0
# 16528                                  Kiniro no Corda 3      3DS  2015.0
# 16542  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS  2015.0
# 16548                Hakuoki: Reimeiroku - Omouhase Kara      PSV  2015.0
# 16565                                          Teslagrad      PSV  2015.0
#
#               Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# new table for top game per year
top_game = pd.merge(d1, df, how='inner')
top_game
# Out:
#       Year  Global_Sales                                              Name  \
# 0   1980.0          4.31                                         Asteroids
# 1   1981.0          4.50                                          Pitfall!
# 2   1982.0          7.81                                           Pac-Man
# 3   1983.0          3.20                                          Baseball
# 4   1984.0         28.31                                         Duck Hunt
# 5   1985.0         40.24                                 Super Mario Bros.
# 6   1986.0          6.51                               The Legend of Zelda
# 7   1987.0          4.38                   Zelda II: The Adventure of Link
# 8   1988.0         17.28                               Super Mario Bros. 3
# 9   1989.0         30.26                                            Tetris
# 10  1990.0         20.61                                 Super Mario World
# ...

# %%
# Top consoles all time (global)
console = df.groupby(['Platform'])['Global_Sales'].agg('sum').reset_index()
console = console.sort_values(by = 'Global_Sales', ascending = False)
console
# Out:
#    Platform  Global_Sales
# 16      PS2       1255.64
# 28     X360        979.96
# 17      PS3        957.84
# 26      Wii        926.71
# 4        DS        822.49
# 15       PS        730.66
# 6       GBA        318.50
# 19      PSP        296.28
# 18      PS4        278.10
# 13       PC        258.82
# 29       XB        258.26
# 5        GB        255.45
# 11      NES        251.07
# 2       3DS        247.46
# 10      N64        218.88
# 23     SNES        200.05
# 7        GC        199.36
# 30     XOne        141.06
# 0      2600         97.08
# 27     WiiU         81.86
# 20      PSV         61.93
# 21      SAT         33.59
# 8       GEN         28.36
# 3        DC         15.97
# 22      SCD          1.87
# 12       NG          1.44
# 25       WS          1.42
# 24     TG16          0.16
# 1       3DO          0.10
# 9        GG          0.04
# 14     PCFX          0.03

# %%
# Top 5 platforms
console.head()
# Out:
#    Platform  Global_Sales
# 16      PS2       1255.64
# 28     X360        979.96
# 17      PS3        957.84
# 26      Wii        926.71
# 4        DS        822.49

# %%
# Top consoles all time (NA)
console = df.groupby(['Platform'])['NA_Sales'].agg('sum').reset_index()
console = console.sort_values(by = 'NA_Sales', ascending = False)
console
# Out:
#    Platform  NA_Sales
# 28     X360    601.05
# 16      PS2    583.84
# 26      Wii    507.71
# 17      PS3    392.26
# 4        DS    390.71
# 15       PS    336.51
# 6       GBA    187.54
# 29       XB    186.69
# 10      N64    139.02
# 7        GC    133.46
# 11      NES    125.94
# 5        GB    114.32
# 19      PSP    108.99
# 18      PS4     96.80
# 13       PC     93.28
# 0      2600     90.60
# 30     XOne     83.19
# 2       3DS     78.87
# 23     SNES     61.23
# 27     WiiU     38.32
# 8       GEN     19.27
# 20      PSV     16.20
# 3        DC      5.43
# 22      SCD      1.00
# 21      SAT      0.72
# 1       3DO      0.00
# 14     PCFX      0.00
# 12       NG      0.00
# 9        GG      0.00
# 24     TG16      0.00
# 25       WS      0.00

# %%
# Top 5 consoles NA
console.head()
# Out:
#    Platform  NA_Sales
# 28     X360    601.05
# 16      PS2    583.84
# 26      Wii    507.71
# 17      PS3    392.26
# 4        DS    390.71

# %%
# Top consoles all time (EU)
console = df.groupby(['Platform'])['EU_Sales'].agg('sum').reset_index()
console = console.sort_values(by = 'EU_Sales', ascending = False)
console
# Out:
#    Platform  EU_Sales
# 17      PS3    343.71
# 16      PS2    339.29
# 28     X360    280.58
# 26      Wii    268.38
# 15       PS    213.60
# 4        DS    194.65
# 13       PC    139.68
# 18      PS4    123.70
# 6       GBA     75.25
# 19      PSP     68.25
# 29       XB     60.95
# 2       3DS     58.52
# 5        GB     47.82
# 30     XOne     45.65
# 10      N64     41.06
# 7        GC     38.71
# 27     WiiU     24.23
# 11      NES     21.15
# 23     SNES     19.04
# 20      PSV     16.33
# 8       GEN      5.52
# 0      2600      5.47
# 3        DC      1.69
# 21      SAT      0.54
# 22      SCD      0.36
# 25       WS      0.00
# 24     TG16      0.00
# 1       3DO      0.00
# 9        GG      0.00
# 12       NG      0.00
# 14     PCFX      0.00

# %%
# Top 5 consoles EU
console.head()
# Out:
#    Platform  EU_Sales
# 17      PS3    343.71
# 16      PS2    339.29
# 28     X360    280.58
# 26      Wii    268.38
# 15       PS    213.60

# %%
# Top consoles all time (JP)
console = df.groupby(['Platform'])['JP_Sales'].agg('sum').reset_index()
console = console.sort_values(by = 'JP_Sales', ascending = False)
console
# Out:
#    Platform  JP_Sales
# 4        DS    175.57
# 15       PS    139.82
# 16      PS2    139.20
# 23     SNES    116.55
# 11      NES     98.65
# 2       3DS     97.35
# 5        GB     85.12
# 17      PS3     79.99
# 19      PSP     76.79
# 26      Wii     69.35
# 6       GBA     47.33
# 10      N64     34.22
# 21      SAT     32.26
# 7        GC     21.58
# 20      PSV     20.96
# 18      PS4     14.30
# 27     WiiU     12.79
# 28     X360     12.43
# 3        DC      8.56
# 8       GEN      2.67
# 12       NG      1.44
# 25       WS      1.42
# 29       XB      1.38
# 22      SCD      0.45
# 30     XOne      0.34
# 13       PC      0.17
# 24     TG16      0.16
# 1       3DO      0.10
# 9        GG      0.04
# 14     PCFX      0.03
# 0      2600      0.00

# %%
# Top 5 consoles JP
console.head()
# Out:
#    Platform  JP_Sales
# 4        DS    175.57
# 15       PS    139.82
# 16      PS2    139.20
# 23     SNES    116.55
# 11      NES     98.65

# %%
# Top consoles all time (other)
console = df.groupby(['Platform'])['Other_Sales'].agg('sum').reset_index()
console = console.sort_values(by = 'Other_Sales', ascending = False)
console
# Out:
#    Platform  Other_Sales
# 16      PS2       193.44
# 17      PS3       141.93
# 28     X360        85.54
# 26      Wii        80.61
# 4        DS        60.53
# 18      PS4        43.36
# 19      PSP        42.19
# 15       PS        40.91
# 13       PC        24.86
# 2       3DS        12.63
# 30     XOne        11.92
# 29       XB         8.72
# 20      PSV         8.45
# 5        GB         8.20
# 6       GBA         7.73
# 27     WiiU         6.45
# 11      NES         5.31
# 7        GC         5.18
# 10      N64         4.38
# 23     SNES         3.22
# 0      2600         0.91
# 8       GEN         0.89
# 3        DC         0.27
# 21      SAT         0.07
# 22      SCD         0.05
# 12       NG         0.00
# 24     TG16         0.00
# 25       WS         0.00
# 9        GG         0.00
# 1       3DO         0.00
# 14     PCFX         0.00

# %%
# Top 5 consoles other
console.head()
# Out:
#    Platform  Other_Sales
# 16      PS2       193.44
# 17      PS3       141.93
# 28     X360        85.54
# 26      Wii        80.61
# 4        DS        60.53

# %%
# Top console per year
console = df.groupby(['Platform', 'Year'])['Global_Sales'].agg('sum').reset_index()
console
# Out:
#     Platform    Year  Global_Sales
# 0       2600  1980.0         11.38
# 1       2600  1981.0         35.77
# 2       2600  1982.0         28.86
# 3       2600  1983.0          5.83
# 4       2600  1984.0          0.27
# ..       ...     ...           ...
# 236       XB  2008.0          0.18
# 237     XOne  2013.0         18.60
# 238     XOne  2014.0         52.43
# 239     XOne  2015.0         57.66
# 240     XOne  2016.0         12.37
#
# [241 rows x 3 columns]

# %%
t2 = console.groupby('Year')['Global_Sales'].max().reset_index()
t2
# Out:
#       Year  Global_Sales
# 0   1980.0         11.38
# 1   1981.0         35.77
# 2   1982.0         28.86
# 3   1983.0         10.96
# 4   1984.0         50.09
# 5   1985.0         53.44
# 6   1986.0         36.41
# 7   1987.0         19.76
# 8   1988.0         45.01
# 9   1989.0         64.98
# 10  1990.0         26.16
# 11  1991.0         16.21
# 12  1992.0         32.98
# 13  1993.0         40.01
# 14  1994.0         35.08
# 15  1995.0         35.92
# 16  1996.0         94.68
# 17  1997.0        136.08
# 18  1998.0        169.58
# 19  1999.0        144.57
# 20  2000.0         96.28
# 21  2001.0        166.43
# 22  2002.0        205.40
# 23  2003.0        184.29
# 24  2004.0        211.78
# 25  2005.0        160.65
# 26  2006.0        137.91
# 27  2007.0        154.97
# 28  2008.0        174.16
# 29  2009.0        210.44
# 30  2010.0        171.05
# 31  2011.0        159.37
# 32  2012.0        109.49
# 33  2013.0        117.39
# 34  2014.0         98.76
# 35  2015.0        115.30
# ...

# %%
t2 = t2.drop(columns = 'Year')

# %%
console = pd.pivot_table(console, values = ['Global_Sales'], index = ['Year', 'Platform'])
console
# Out:
#                  Global_Sales
# Year   Platform
# 1980.0 2600             11.38
# 1981.0 2600             35.77
# 1982.0 2600             28.86
# 1983.0 2600              5.83
#        NES              10.96
# ...                       ...
# 2016.0 X360              0.83
#        XOne             12.37
# 2017.0 PS4               0.03
#        PSV               0.02
# 2020.0 DS                0.29
#
# [241 rows x 1 columns]

# %%
t1 = console.groupby(['Year'])['Global_Sales'].idxmax().reset_index()
t1
# Out:
#       Year    Global_Sales
# 0   1980.0  (1980.0, 2600)
# 1   1981.0  (1981.0, 2600)
# 2   1982.0  (1982.0, 2600)
# 3   1983.0   (1983.0, NES)
# 4   1984.0   (1984.0, NES)
# 5   1985.0   (1985.0, NES)
# 6   1986.0   (1986.0, NES)
# 7   1987.0   (1987.0, NES)
# 8   1988.0   (1988.0, NES)
# 9   1989.0    (1989.0, GB)
# 10  1990.0  (1990.0, SNES)
# 11  1991.0  (1991.0, SNES)
# 12  1992.0  (1992.0, SNES)
# 13  1993.0  (1993.0, SNES)
# 14  1994.0  (1994.0, SNES)
# 15  1995.0    (1995.0, PS)
# 16  1996.0    (1996.0, PS)
# 17  1997.0    (1997.0, PS)
# 18  1998.0    (1998.0, PS)
# 19  1999.0    (1999.0, PS)
# 20  2000.0    (2000.0, PS)
# 21  2001.0   (2001.0, PS2)
# 22  2002.0   (2002.0, PS2)
# 23  2003.0   (2003.0, PS2)
# 24  2004.0   (2004.0, PS2)
# 25  2005.0   (2005.0, PS2)
# 26  2006.0   (2006.0, Wii)
# 27  2007.0   (2007.0, Wii)
# 28  2008.0   (2008.0, Wii)
# 29  2009.0   (2009.0, Wii)
# 30  2010.0  (2010.0, X360)
# 31  2011.0   (2011.0, PS3)
# 32  2012.0   (2012.0, PS3)
# ...

# %%
t1['year'] = t1['Global_Sales'].astype(str).str[1:5]
t1['year']
# Out:
# 0     1980
# 1     1981
# 2     1982
# 3     1983
# 4     1984
# 5     1985
# 6     1986
# 7     1987
# 8     1988
# 9     1989
# 10    1990
# 11    1991
# 12    1992
# 13    1993
# 14    1994
# 15    1995
# 16    1996
# 17    1997
# 18    1998
# 19    1999
# 20    2000
# 21    2001
# 22    2002
# 23    2003
# 24    2004
# 25    2005
# 26    2006
# 27    2007
# 28    2008
# 29    2009
# 30    2010
# 31    2011
# 32    2012
# 33    2013
# 34    2014
# 35    2015
# 36    2016
# 37    2017
# 38    2020
# Name: year, dtype: object

# %%
t1['platform'] = t1['Global_Sales'].astype(str).str[8:-1]
t1['platform']
# Out:
# 0      '2600'
# 1      '2600'
# 2      '2600'
# 3       'NES'
# 4       'NES'
# 5       'NES'
# 6       'NES'
# 7       'NES'
# 8       'NES'
# 9        'GB'
# 10     'SNES'
# 11     'SNES'
# 12     'SNES'
# 13     'SNES'
# 14     'SNES'
# 15       'PS'
# 16       'PS'
# 17       'PS'
# 18       'PS'
# 19       'PS'
# 20       'PS'
# 21      'PS2'
# 22      'PS2'
# 23      'PS2'
# 24      'PS2'
# 25      'PS2'
# 26      'Wii'
# 27      'Wii'
# 28      'Wii'
# 29      'Wii'
# 30     'X360'
# 31      'PS3'
# 32      'PS3'
# 33      'PS3'
# 34      'PS4'
# 35      'PS4'
# 36      'PS4'
# 37      'PS4'
# 38       'DS'
# Name: platform, dtype: object

# %%
t1 = t1.drop(columns = ['Global_Sales', 'Year'])
t1
# Out:
#     year platform
# 0   1980   '2600'
# 1   1981   '2600'
# 2   1982   '2600'
# 3   1983    'NES'
# 4   1984    'NES'
# 5   1985    'NES'
# 6   1986    'NES'
# 7   1987    'NES'
# 8   1988    'NES'
# 9   1989     'GB'
# 10  1990   'SNES'
# 11  1991   'SNES'
# 12  1992   'SNES'
# 13  1993   'SNES'
# 14  1994   'SNES'
# 15  1995     'PS'
# 16  1996     'PS'
# 17  1997     'PS'
# 18  1998     'PS'
# 19  1999     'PS'
# 20  2000     'PS'
# 21  2001    'PS2'
# 22  2002    'PS2'
# 23  2003    'PS2'
# 24  2004    'PS2'
# 25  2005    'PS2'
# 26  2006    'Wii'
# 27  2007    'Wii'
# 28  2008    'Wii'
# 29  2009    'Wii'
# 30  2010   'X360'
# 31  2011    'PS3'
# 32  2012    'PS3'
# 33  2013    'PS3'
# 34  2014    'PS4'
# 35  2015    'PS4'
# 36  2016    'PS4'
# 37  2017    'PS4'
# 38  2020     'DS'

# %%
# new table for top platform per year
t3 = pd.merge(t1, t2, left_index=True, right_index=True)
t3
# Out:
#     year platform  Global_Sales
# 0   1980   '2600'         11.38
# 1   1981   '2600'         35.77
# 2   1982   '2600'         28.86
# 3   1983    'NES'         10.96
# 4   1984    'NES'         50.09
# 5   1985    'NES'         53.44
# 6   1986    'NES'         36.41
# 7   1987    'NES'         19.76
# 8   1988    'NES'         45.01
# 9   1989     'GB'         64.98
# 10  1990   'SNES'         26.16
# 11  1991   'SNES'         16.21
# 12  1992   'SNES'         32.98
# 13  1993   'SNES'         40.01
# 14  1994   'SNES'         35.08
# 15  1995     'PS'         35.92
# 16  1996     'PS'         94.68
# 17  1997     'PS'        136.08
# 18  1998     'PS'        169.58
# 19  1999     'PS'        144.57
# 20  2000     'PS'         96.28
# 21  2001    'PS2'        166.43
# 22  2002    'PS2'        205.40
# 23  2003    'PS2'        184.29
# 24  2004    'PS2'        211.78
# 25  2005    'PS2'        160.65
# 26  2006    'Wii'        137.91
# 27  2007    'Wii'        154.97
# ...

# %%
# Top 5 publishers (count)
a = df.Publisher.value_counts().head()
a
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
# Name: Publisher, dtype: int64

# %%
a.plot(kind = 'bar', figsize = (16, 9), xlabel = 'publisher', ylabel = 'Count', title = 'Top 5 publisher (games made)')
# Out:
# <AxesSubplot:title={'center':'Top 5 publisher (games made)'}, xlabel='publisher', ylabel='Count'>

# %%
# Top 5 performing publishers (revenue/sales)
publisher = df.groupby(['Publisher'])['Global_Sales'].sum().reset_index().sort_values(by = 'Global_Sales', ascending = False).head()
publisher
# Out:
#                        Publisher  Global_Sales
# 359                     Nintendo       1786.56
# 138              Electronic Arts       1110.32
# 21                    Activision        727.46
# 456  Sony Computer Entertainment        607.50
# 525                      Ubisoft        474.72

# %%
publisher.plot(kind = 'bar', figsize = (16, 9), xlabel = 'publisher', ylabel = 'Global_Sales', title = 'Top 5 Games For publisher sales')
# Out:
# <AxesSubplot:title={'center':'Top 5 Games For publisher sales'}, xlabel='publisher', ylabel='Global_Sales'>
